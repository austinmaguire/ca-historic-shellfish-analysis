# %%
import pandas as pd
from pathlib import Path

# Get the path to the data file
data_path = Path('..') / 'data' / 'raw' / 'california_fish_landings_1928_2002.csv'
ca_all_fish_landings = pd.read_csv(data_path)

# Get unique fish species and sort alphabetically
species = sorted(ca_all_fish_landings['fish'].unique())

# Print the list in a clean format
print(f"List of {len(species)} unique species:\n")
print("=" * 50)
for i, fish in enumerate(species, 1):
    print(f"{i:3d}. {fish}")

"""
# Moving forward exports to .csv files are commented out for future referencing
species_df = pd.DataFrame(species, columns=['Species'])
species_df.to_csv('california_fish_species_list.csv', index=True, index_label='Number')
print("Species list saved to 'california_fish_species_list.csv'") 
"""
# Out:
# List of 341 unique species:
#
# ==================================================
#   1. Abalone, Black
#   2. Abalone, Flat
#   3. Abalone, Green
#   4. Abalone, Pink
#   5. Abalone, Pinto
#   6. Abalone, Red
#   7. Abalone, Threaded
#   8. Abalone, Unspecified
#   9. Abalone, White
#  10. Anchovy, Deepbody
#  11. Anchovy, Northern
#  12. Barnacle
#  13. Barracuda, California
#  14. Bass, Barred Sand
#  15. Bass, Giant Sea
#  16. Bass, Kelp
#  17. Bass, Rock
#  18. Bass, Spotted Sand
#  19. Bass, Striped
#  20. Blackfish, Sacramento
#  21. Blacksmith
#  22. Bonefish
#  23. Bonito, Pacific
#  24. Box Crab
#  25. Butterfish, Pacific
#  26. Cabezon
#  27. Cabrilla, Spotted
#  28. Carp
#  29. Catfish
#  30. Chiton
#  31. Clam, California Jackknife
#  32. Clam, Common Washington
#  33. Clam, Gaper
#  34. Clam, Native Littleneck
#  35. Clam, Nothern Razor
#  36. Clam, Pismo
#  37. Clam, Purple
#  38. Clam, Rosy Razor
#  39. Clam, Soft Shelled
#  40. Clam, Unspecified
#  41. Cod, Pacific
#  42. Corbina, California
#  43. Corvina, Shortfin
#  44. Crab, Brown Rock
#  45. Crab, Claws
#  46. Crab, Dungeness
#  47. Crab, King
#  48. Crab, Pelagic Red
#  49. Crab, Red Rock
#  50. Crab, Rock
#  51. Crab, Sand
#  52. Crab, Shore
#  53. Crab, Spider
#  54. Crab, Tanner
#  55. Crab, Yellow Rock
#  56. Crayfish
#  57. Croaker, Black
#  58. Croaker, Various Species
#  59. Croaker, White
#  60. Croaker, Yellowfin
#  61. Crustacean, Unspecified
#  62. Cucumber, Sea
#  63. Cusk-Eel, Spotted
#  64. Dolphinfish
#  65. Echinod, Unspecified
#  66. Eel
#  67. Eel, Blenny
#  68. Eel, California Moray
#  69. Escolar
#  70. Eulachon
#  71. Flounder, Arrowtooth
#  72. Flounder, Starry
#  73. Flounder, Unclassified
#  74. Flyingfish
#  75. Frogs
#  76. Garibaldi
#  77. Goby, Bluebanded
#  78. Goby, Yellowfin
#  79. Greenling, Kelp
#  80. Grenadiers
#  81. Grouper
#  82. Grouper, Broomtail
#  83. Grunion, California
#  84. Guitarfish, Shovelnose
#  85. Hagfish
#  86. Halfmoon
#  87. Halibut, California
#  88. Halibut, Pacific
#  89. Halibut, Unspecified
#  90. Hardhead
#  91. Herring Roe On Kelp
#  92. Herring, Pacific
#  93. Herring, Round
#  94. Herring, Whole Fish With Roe
#  95. Hitch
#  96. Invertebrates, Colonial
#  97. Jack Crevalle
#  98. Jacks
#  99. Kahawai
# 100. Kelpfishes
# 101. Killifish, California
# 102. Limpet, Unspecified
# 103. Lingcod
# 104. Lizardfish, California
# 105. Lobster, California Spiny
# 106. Louvar
# 107. Mackerel, Bullet
# 108. Mackerel, Jack
# 109. Mackerel, Pacific
# 110. Mackerel, Unspecified
# 111. Marlin, Striped
# 112. Midshipman, Plainfin
# 113. Mola, Common
# 114. Mollusk, Unspecified
# 115. Monkeyface Eel
# 116. Mudsucker, Longjaw
# 117. Mullet, Striped
# 118. Mussel
# 119. Needlefish, California
# 120. Octopus, Unspecified
# 121. Oilfish
# 122. Opah
# 123. Opaleye
# 124. Oyster, California
# 125. Oyster, Eastern
# 126. Oyster, European Flat
# 127. Oyster, Giant Pacific
# 128. Oyster, Unspecified
# 129. Perch
# 130. Perch, Pacific Ocean
# 131. Pikeminnow, Sacramento
# 132. Pomfret, Pacific
# 133. Prawn, Golden
# 134. Prawn, Ridgeback
# 135. Prawn, Spotted
# 136. Prawn, Unspecified
# 137. Queenfish
# 138. Ratfish
# 139. Ray
# 140. Ray, Bat
# 141. Ray, Pacific Electric
# 142. Rockfish, Aurora
# 143. Rockfish, Bank
# 144. Rockfish, Black
# 145. Rockfish, Black-And-Yellow
# 146. Rockfish, Blackgill
# 147. Rockfish, Blue
# 148. Rockfish, Bocaccio
# 149. Rockfish, Bronzespotted
# 150. Rockfish, Brown
# 151. Rockfish, Calico
# 152. Rockfish, Chameleon
# 153. Rockfish, Chilipepper
# 154. Rockfish, China
# 155. Rockfish, Copper
# 156. Rockfish, Cowcod
# 157. Rockfish, Darkblotched
# 158. Rockfish, Flag
# 159. Rockfish, Gopher
# 160. Rockfish, Grass
# 161. Rockfish, Greenblotched
# 162. Rockfish, Greenspotted
# 163. Rockfish, Greenstriped
# 164. Rockfish, Group Blue/Black
# 165. Rockfish, Group Bocaccio/Chilir
# 166. Rockfish, Group Bolina
# 167. Rockfish, Group Canary/Vermillrock
# 168. Rockfish, Group Deep Red
# 169. Rockfish, Group Gopher
# 170. Rockfish, Group Red
# 171. Rockfish, Group Rosefish
# 172. Rockfish, Group Small Red
# 173. Rockfish, Honeycomb
# 174. Rockfish, Kelp
# 175. Rockfish, Mexican
# 176. Rockfish, Nominal Canary
# 177. Rockfish, Olive
# 178. Rockfish, Pink
# 179. Rockfish, Pinkrose
# 180. Rockfish, Quillback
# 181. Rockfish, Redbanded
# 182. Rockfish, Rosethorn
# 183. Rockfish, Rosy
# 184. Rockfish, Shortbelly
# 185. Rockfish, Speckled
# 186. Rockfish, Splitnose
# 187. Rockfish, Squarespot
# 188. Rockfish, Starry
# 189. Rockfish, Stripetail
# 190. Rockfish, Swordspine
# 191. Rockfish, Treefish
# 192. Rockfish, Unspecified
# 193. Rockfish, Unspecified Nearshorer
# 194. Rockfish, Unspecified Shelf
# 195. Rockfish, Unspecified Slope
# 196. Rockfish, Vermillion
# 197. Rockfish, Widow
# 198. Rockfish, Yelloweye
# 199. Rockfish, Yellowtail
# 200. Sablefish
# 201. Sailfish
# 202. Salema
# 203. Salmon
# 204. Salmon Roe, King
# 205. Salmon, Chum
# 206. Salmon, King
# 207. Salmon, Pink
# 208. Salmon, Silver
# 209. Sanddab
# 210. Sanddab, Longfin
# 211. Sanddab, Pacific
# 212. Sanddab, Speckled
# 213. Sardine, Pacific
# 214. Sargo
# 215. Saury, Pacific
# 216. Scallop, Unspecified
# 217. Scorpionfish, California
# 218. Sculpin, Pacific Staghorn
# 219. Sculpin, Yellowchin
# 220. Sea Hares
# 221. Sea Slug
# 222. Sea Stars
# 223. Seabass, White
# 224. Senorita
# 225. Shad, American
# 226. Shad, Threadfin
# 227. Shark
# 228. Shark, Basking
# 229. Shark, Bigeye Thresher
# 230. Shark, Black Tip
# 231. Shark, Blue
# 232. Shark, Bonito (Mako)
# 233. Shark, Brown Smooth
# 234. Shark, Common Thresher
# 235. Shark, Cow
# 236. Shark, Dusky
# 237. Shark, Gray Smoothhound
# 238. Shark, Horn
# 239. Shark, Leopard
# 240. Shark, Pacific Angel
# 241. Shark, Pelagic Thresher
# 242. Shark, Salmon
# 243. Shark, Sevengill
# 244. Shark, Sixgill
# 245. Shark, Smooth Hammerhead
# 246. Shark, Soupfin
# 247. Shark, Spiny Dogfish
# 248. Shark, Swell
# 249. Shark, White
# 250. Sheephead, California
# 251. Shrimp, Bay
# 252. Shrimp, Brine
# 253. Shrimp, Coonstripe
# 254. Shrimp, Ghost
# 255. Shrimp, Pacific Ocean
# 256. Shrimp, Red Rock
# 257. Shrimp, Unspecified
# 258. Sierra
# 259. Skate
# 260. Skate, Big
# 261. Skate, California
# 262. Skate, Thorny
# 263. Smelt
# 264. Smelt, Atherinid
# 265. Smelt, Jacksmelt
# 266. Smelt, Night
# 267. Smelt, Surf
# 268. Smelt, Topsmelt
# 269. Smelt, True
# 270. Smelt, Whitebait
# 271. Snail, Sea
# 272. Snapper -Mexico-
# 273. Sole, Bigmouth
# 274. Sole, Butter
# 275. Sole, C-O
# 276. Sole, Curlfin
# 277. Sole, Dover
# 278. Sole, English
# 279. Sole, Fantail
# 280. Sole, Petrale
# 281. Sole, Rex
# 282. Sole, Rock
# 283. Sole, Sand
# 284. Sole, Slender
# 285. Sole, Unclassified
# 286. Split-Tail
# 287. Squid, Jumbo
# 288. Squid, Market
# 289. Stickleback, Threespine
# 290. Stingray
# 291. Sturgeon
# 292. Sucker, Western
# 293. Surfperch
# 294. Surfperch, Barred
# 295. Surfperch, Black
# 296. Surfperch, Calico
# 297. Surfperch, Dwarf
# 298. Surfperch, Pile
# 299. Surfperch, Pink
# 300. Surfperch, Rainbow
# 301. Surfperch, Redtail
# 302. Surfperch, Rubberlip
# 303. Surfperch, Shiner
# 304. Surfperch, Walleye
# 305. Surfperch, White
# 306. Swordfish
# 307. Thornyhead
# 308. Thornyhead, Longspine
# 309. Thornyhead, Shortspine
# 310. Tomcod, Pacific
# 311. Tonguefish, California
# 312. Triggerfish
# 313. Tuna, Albacore
# 314. Tuna, Bigeye
# 315. Tuna, Blackfin
# 316. Tuna, Bluefin
# 317. Tuna, Skipjack
# 318. Tuna, Skipjack, Black
# 319. Tuna, Unspecified
# 320. Tuna, Yellowfin
# 321. Turbot, Diamond
# 322. Turbot, Hornyhead
# 323. Turbot, Spotted
# 324. Turbot, Unspecified
# 325. Turtles, Freshwater
# 326. Turtles, Marine
# 327. Unspecified Fish
# 328. Unspecified Trawled Fish
# 329. Urchin, Lytechinus
# 330. Urchin, Purple Sea
# 331. Urchin, Red Sea
# 332. Urchin, Unspecified
# 333. Wahoo
# 334. Whelk
# 335. Whitefish, Ocean
# 336. Whiting, Pacific
# 337. Wolf-Eel
# 338. Worms, Marine
# 339. Wrasse, Rock
# 340. Yellowtail
# 341. Zebraperch
# '\n# Moving forward exports to .csv files are commented out for future referencing\nspecies_df = pd.DataFrame(species, columns=[\'Species\'])\nspecies_df.to_csv(\'california_fish_species_list.csv\', index=True, index_label=\'Number\')\nprint("Species list saved to \'california_fish_species_list.csv\'") \n'

# %%
# Create some basic statistics about species naming patterns
print("\nSpecies Categories Analysis:")
print("=" * 50)

# Count species by certain categories
rockfish_count = sum(1 for s in species if 'Rockfish' in s)
shark_count = sum(1 for s in species if 'Shark' in s)
tuna_count = sum(1 for s in species if 'Tuna' in s)
salmon_count = sum(1 for s in species if 'Salmon' in s)

print(f"\nRockfish species: {rockfish_count}")
print(f"Shark species: {shark_count}")
print(f"Tuna species: {tuna_count}")
print(f"Salmon species: {salmon_count}")
# Out:
# Species Categories Analysis:
# ==================================================
#
# Rockfish species: 58
# Shark species: 23
# Tuna species: 8
# Salmon species: 7

# %%
ca_all_fish_landings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148300 entries, 0 to 2148299
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   time      object
#  1   year      int64
#  2   fish      object
#  3   port      object
#  4   landings  int64
# dtypes: int64(2), object(3)
# memory usage: 82.0+ MB

# %%
crustaceans = [
    "barnacle",
    "box crab",
    "crab, claws",
    "crab, dungeness",
    "crab, king",
    "crab, pelagic red",
    "crab, rock",
    "crab, brown rock",
    "crab, red rock",
    "crab, yellow rock",
    "crab, sand",
    "crab, shore",
    "crab, spider",
    "crab, tanner",
    "crayfish",
    "lobster, california spiny", 
    "prawn, golden",
    "prawn, ridgeback",
    "prawn, spotted",
    "prawn, unspecified",
    "shrimp, bay",
    "shrimp, brine",
    "shrimp, coonstripe",
    "shrimp, ghost",
    "shrimp, pacific ocean",
    "shrimp, red rock",
    "shrimp, unspecified",
    "crustacean, unspecified"
]

echinoderms = [
    "cucumber, sea",
    "echinoderm, unspecified",
    "sea stars",
    "urchin, lytechinus",
    "urchin, purple sea",
    "urchin, red sea",
    "urchin, unspecified"
]

mollusks = [
    "abalone, black",
    "abalone, flat",
    "abalone, green",
    "abalone, pink",
    "abalone, white", 
    "abalone, threaded",
    "abalone, pinto",
    "abalone, red",
    "abalone, unspecified",
    "chiton",
    "clam, gaper",
    "clam, california jackknife",
    "clam, native littleneck",
    "clam, northern razor",
    "clam, purple",
    "clam, pismo",
    "clam, rosy razor",
    "clam, soft-shelled",
    "clam, common washington", 
    "clam, unspecified",
    "limpet, unspecified",
    "mollusk, unspecified", 
    "mussel",
    "octopus, unspecified",
    "oyster, california",
    "oyster, eastern",
    "oyster, european flat",
    "oyster, giant pacific",
    "oyster, unspecified",
    "scallop, unspecified",
    "sea hares",
    "sea slug",
    "snail, sea",
    "squid, jumbo",
    "squid, market",
    "whelk"
]

# %%
# Combine all shellfish genera/phyla lists into one
shellfish = crustaceans + echinoderms + mollusks

# Convert shellfish list to lowercase
shellfish_lower = [x.lower() for x in shellfish]

# Create new DataFrame, converting 'fish' column to lowercase first
ca_all_fish_landings['fish'] = ca_all_fish_landings['fish'].str.lower()
ca_all_shellfish_landings = ca_all_fish_landings[ca_all_fish_landings['fish'].isin(shellfish_lower)].copy()

# Print info about the new DataFrame
print(f"Original DataFrame rows: {len(ca_all_fish_landings)}")
print(f"Shellfish DataFrame rows: {len(ca_all_shellfish_landings)}")
print("\nShellfish DataFrame info:")
print(ca_all_shellfish_landings.info())
# Out:
# Original DataFrame rows: 2148300
# Shellfish DataFrame rows: 428400
#
# Shellfish DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 428400 entries, 0 to 2104199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   time      428400 non-null  object
#  1   year      428400 non-null  int64
#  2   fish      428400 non-null  object
#  3   port      428400 non-null  object
#  4   landings  428400 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 19.6+ MB
# None

# %%
# Check that just the shellfish species have been moved to the new Shellfish DataFrame 
# Rename 'fish' to 'species'

ca_all_shellfish_landings = ca_all_shellfish_landings.rename(columns={'fish':'species'})

ca_all_shellfish_landings['species'].unique()
# Out:
# array(['abalone, black', 'abalone, flat', 'abalone, green',
#        'abalone, pink', 'abalone, pinto', 'abalone, red',
#        'abalone, threaded', 'abalone, unspecified', 'abalone, white',
#        'barnacle', 'box crab', 'chiton', 'clam, california jackknife',
#        'clam, common washington', 'clam, gaper',
#        'clam, native littleneck', 'clam, pismo', 'clam, purple',
#        'clam, rosy razor', 'clam, unspecified', 'crab, brown rock',
#        'crab, claws', 'crab, dungeness', 'crab, king',
#        'crab, pelagic red', 'crab, red rock', 'crab, rock', 'crab, sand',
#        'crab, shore', 'crab, spider', 'crab, tanner', 'crab, yellow rock',
#        'crayfish', 'crustacean, unspecified', 'cucumber, sea',
#        'limpet, unspecified', 'lobster, california spiny',
#        'mollusk, unspecified', 'mussel', 'octopus, unspecified',
#        'oyster, california', 'oyster, eastern', 'oyster, european flat',
#        'oyster, giant pacific', 'oyster, unspecified', 'prawn, golden',
#        'prawn, ridgeback', 'prawn, spotted', 'prawn, unspecified',
#        'scallop, unspecified', 'sea hares', 'sea slug', 'sea stars',
#        'shrimp, bay', 'shrimp, brine', 'shrimp, coonstripe',
#        'shrimp, ghost', 'shrimp, pacific ocean', 'shrimp, red rock',
#        'shrimp, unspecified', 'snail, sea', 'squid, jumbo',
#        'squid, market', 'urchin, lytechinus', 'urchin, purple sea',
#        'urchin, red sea', 'urchin, unspecified', 'whelk'], dtype=object)

# %%
# Specify more common fisheries for investigation - 
abalone = [
    "abalone, black",
    "abalone, flat",
    "abalone, green",
    "abalone, pink",
    "abalone, white",
    "abalone, pinto",
    "abalone, red",
    "abalone, threaded",
    "abalone, unspecified"
]

clams = [
    "clam, gaper",
    "clam, california jackknife",
    "clam, native littleneck",
    "clam, pismo",
    "clam, purple",
    "clam, rosy razor",
    "clam, common washington",
    "clam, unspecified"
]

crabs = [
    "crab, dungeness",
    "crab, rock",
    "crab, brown rock",
    "crab, red rock",
    "crab, yellow rock",
    "crab, king",
    "crab, spider",
    "crab, tanner"
]

oysters = [
    "oyster, california",
    "oyster, eastern",
    "oyster, european flat",
    "oyster, giant pacific",
    "oyster, unspecified"
]

shrimp_prawn = [
    "shrimp, pacific ocean",
    "shrimp, bay",
    "shrimp, red rock",
    "prawn, ridgeback",
    "prawn, spotted",
    "prawn, golden",
    "shrimp, unspecified",
    "prawn, unspecified"
]

# %%
# Combine all common shellfish groups
common_shellfish = abalone + clams + crabs + oysters + shrimp_prawn

# Convert common shellfish list to lowercase
common_shellfish_lower = [x.lower() for x in shellfish]

# %%
# Rename the first DataFrame (with all shellfish species)
all_shellfish_landings = ca_all_fish_landings[ca_all_fish_landings['fish'].isin(shellfish_lower)].copy()

# Create new DataFrame with only common shellfish species
ca_shellfish_landings = ca_all_fish_landings[ca_all_fish_landings['fish'].isin(common_shellfish_lower)].copy()



# Print info about both DataFrames
print(f"Original DataFrame rows: {len(ca_all_fish_landings)}")
print(f"All Shellfish DataFrame rows: {len(all_shellfish_landings)}")
print(f"Common Shellfish DataFrame rows: {len(ca_shellfish_landings)}")
print("\nCommon Shellfish DataFrame info:")
print(ca_shellfish_landings.info())

# Optionally save to CSV
# all_shellfish_landings.to_csv('all_shellfish_landings.csv', index=False)
# ca_shellfish_landings.to_csv('ca_shellfish_landings2.csv', index=False)

#TODO:? issue with all_shellfish_landings not lowered and failing to match with the common_shellfish_lower? 
# Working off saved ca_shellfish_landings.csv for next notebook
# Out:
# Original DataFrame rows: 2148300
# All Shellfish DataFrame rows: 428400
# Common Shellfish DataFrame rows: 428400
#
# Common Shellfish DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 428400 entries, 0 to 2104199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   time      428400 non-null  object
#  1   year      428400 non-null  int64
#  2   fish      428400 non-null  object
#  3   port      428400 non-null  object
#  4   landings  428400 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 19.6+ MB
# None
